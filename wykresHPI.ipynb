# %%
import pandas as pd

# %%
import numpy as np

# %%
df = pd.read_excel(r'C:\Users\faron\OneDrive\Pulpit\dane_nieruchomosci_michal_faron.xlsx')

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
col_list = df["Kraj"].values.tolist()

# %%
col_list1 = (list(set(col_list)))

# %%
col_list1
# Out:
# ['Italy',
#  'Iceland',
#  'Portugal',
#  'Slovakia',
#  'Ireland',
#  'Belgium',
#  'Bulgaria',
#  'Spain',
#  'Estonia',
#  'Sweden',
#  'Poland',
#  'Norway',
#  'Netherlands',
#  'Germany',
#  'Lithuania',
#  'Hungary',
#  'France',
#  'Cyprus',
#  'Slovenia',
#  'Luxembourg',
#  'Croatia',
#  'Latvia',
#  'United Kingdom',
#  'Czechia',
#  'Austria',
#  'Malta',
#  'Denmark',
#  'Romania',
#  'Finland']

# %%
m=0
fig, axes = plt.subplots(1, 29, figsize=(35,10), sharey=True)
for f in col_list1:
    axes[m].scatter(x='Rok', y='HPI', data=df[df['Kraj'] == col_list1[m]])
    axes[m].set_title(col_list1[m])
    axes[m].grid(True)
    m+=1
